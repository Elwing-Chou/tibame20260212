# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260212/blob/main/tibame20260305.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list: 清單(同類型的很多東西)
# dict: 字典(聚集欄位來表示一個複雜東西)
student = {
    "姓名":"Elwing",
    "身高":175,
}
print(student["姓名"])
# set: 不重複的集合
# tuple: 簡化版的字典
color = {
    "r":255,
    "g":255,
    "b":255
}
color = (255, 255, 255)
student = ("Elwing", 175, 79)
print(student[0])
# Out:
# Elwing
# Elwing

# %%
# 程式型態裡面的型態基本分兩類,
# 可改的: list
# 不可改的: int/float/str/tuple
# 不可改的東西才能當作key
s = ("Elwing", 175)
board = {
    (0, 0):"炮"
}
print(board)
# Out:
# {(0, 0): '炮'}
